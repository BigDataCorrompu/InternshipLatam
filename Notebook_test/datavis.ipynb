# %%
import sys
sys.path.append('../ingestion/python/src')
sys.path.append('../ingestion/raw')
from mapper import *
from database import *
from utils import *
from dataclasses import fields
import pandas as pd
import json
RAW_PATH = '../ingestion/raw'  # ← chemin relatif depuis ton notebook

# %%
raw = load_json(f'{RAW_PATH}/2026-06-08', 'jsearch_search')
df = pd.DataFrame(raw.get('raw'))
df
# Out:
#                                               params  \
# 0  {'location': 'Santiago Chile', 'num_pages': 1,...
# 1  {'location': 'Buenos Aires Argentina', 'num_pa...
# 2  {'location': 'Montevideo Uruguay', 'num_pages'...
# 3  {'location': 'Santiago Chile', 'num_pages': 1,...
# 4  {'location': 'Buenos Aires Argentina', 'num_pa...
# 5  {'location': 'Montevideo Uruguay', 'num_pages'...
#
#                                                  raw
# 0  {'data': {'jobs': [{'job_id': 'qL_yhbk6DtFWkwE...
# 1                             {'data': {'jobs': []}}
# 2                             {'data': {'jobs': []}}
# 3  {'data': {'jobs': [{'job_id': 'p84uhyMNToTStD2...
# 4                             {'data': {'jobs': []}}
# 5                             {'data': {'jobs': []}}
