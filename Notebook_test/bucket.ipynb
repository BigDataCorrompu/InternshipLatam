# %%
import sys
sys.path.append("../ingestion/python/src")


from utils import *
from bucket import Bucket


import os
from dotenv import load_dotenv
load_dotenv(override=True)

bt = Bucket()

# %% [markdown]
# # Bucket listings ✅

# %%
print("Files listings")
l = bt.list_all_files()
print(l)

print("Files listings")
f = bt.list_folder('dest')
print(f)
# Out:
# Files listings
# {'job_offer/2026/07/careerjet/2026-07-13_careerjet.json': {'id': '4_z81f468d8395c34d19ffb0517_f105386339182666b_d20260714_m225815_c005_v0501038_t0011_u01784069895363', 'size': 49106, 'date': 1784069895363}, 'job_offer/2026/07/careerjet/2026-07-14_careerjet.json': {'id': '4_z81f468d8395c34d19ffb0517_f1023ffa5e6b23278_d20260715_m190011_c005_v0501031_t0011_u01784142011430', 'size': 241968, 'date': 1784142011430}, 'job_offer/2026/07/careerjet/20260715T190000_careerjet.json': {'id': '4_z81f468d8395c34d19ffb0517_f10573e94e0e3cee6_d20260716_m190010_c005_v0501035_t0028_u01784228410185', 'size': 213364, 'date': 1784228410185}, 'job_offer/2026/07/careerjet/20260716T190000_careerjet.json': {'id': '4_z81f468d8395c34d19ffb0517_f1158e74e89ef20a1_d20260717_m190011_c005_v0501004_t0017_u01784314811043', 'size': 225928, 'date': 1784314811043}, 'job_offer/2026/07/careerjet/20260717T190000_careerjet.json': {'id': '4_z81f468d8395c34d19ffb0517_f1040fa704805f282_d20260718_m190012_c005_v0501044_t0027_u01784401212098', 'size': 259331, 'date': 1784401212098}, 'job_offer/2026/07/jsearch/2026-07-10_jsearch.json': {'id': '4_z81f468d8395c34d19ffb0517_f115ea8ad4171eb80_d20260714_m230005_c005_v0501041_t0014_u01784070005420', 'size': 294787, 'date': 1784070005420}, 'job_offer/2026/07/jsearch/2026-07-14_jsearch.json': {'id': '4_z81f468d8395c34d19ffb0517_f10141bd415c94a26_d20260714_m230057_c005_v0501041_t0011_u01784070057536', 'size': 296782, 'date': 1784070057536}, 'job_offer/2026/07/jsearch/20260713T200000_jsearch.json': {'id': '4_z81f468d8395c34d19ffb0517_f1082b0de568eb490_d20260716_m200054_c005_v0501046_t0039_u01784232054089', 'size': 247647, 'date': 1784232054089}, 'test/bucket.py': {'id': '4_z81f468d8395c34d19ffb0517_f102f33e43d7a951d_d20260712_m222445_c005_v0501043_t0002_u01783895085817', 'size': 5126, 'date': 1783895085817}}
# Files listings
# {}

# %% [markdown]
# # Bucket upload ✅

# %%
local_path = "../ingestion/python/src/bucket.py"
bucket_path = "test/bucket.py"

filedata = bt.upload_file(bucket_path, local_path)
print(filedata)
# Out:
# {'name': 'test/bucket.py', 'id': '4_z81f468d8395c34d19ffb0517_f102f33e43d7a951d_d20260712_m222445_c005_v0501043_t0002_u01783895085817', 'size': 5126}

# %% [markdown]
# # Bucket Move ✅

# %%
origin = "test/bucket.py"
destination = "dest/bucket.py"
file_id = filedata['id']

filedata = bt.move_file(origin, destination, file_id)
print(filedata)
# Out:
# [B2] file_name=test/bucket.py, file_id=4_z81f468d8395c34d19ffb0517_f1126d8b572f62335_d20260708_m222530_c005_v0521006_t0018_u01783549530284 status=not_found
# {'name': 'dest/bucket.py', 'id': '4_z81f468d8395c34d19ffb0517_f117f0ef1640a9b38_d20260708_m222617_c005_v0501041_t0026_u01783549577932', 'size': 5126}

# %% [markdown]
# # Bucket download by name ✅
# # Bucket download by id ✅

# %%
local = "./test_bucket"
file_id = filedata['id']
name = filedata['name']

bt.download_file_by_id(file_id, local)
bt.download_file_by_name(name, local)
# Out:
# True

# %% [markdown]
# # Bucket delete by id ✅

# %%
file_id = "4_z81f468d8395c34d19ffb0517_f116356ffe16e0e3a_d20260708_m220311_c005_v0501004_t0049_u01783548191100"
name = "test/bucket.py"

bt.delete_file_by_id(file_id, name)
